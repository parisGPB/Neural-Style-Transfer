# %% [markdown]
# # BASIC STYLE TRANSFER

# %% [markdown]
# ## Imports
# This notebook tries to explain the intrinsics of the most basic implementation of Style Transfer. Please, refer to the `Readme.md` file to see the general description of the project and the basic explanation.

# %%
import numpy as np
import os
import sys
from keras import backend as K
from argparse import ArgumentParser
from google.colab import files

# !pip install Pillow
from PIL import Image
from IPython.display import Image, display
import matplotlib.pyplot as plt

from __future__ import print_function
from __future__ import division
from __future__ import absolute_import

from scipy.misc import imread, imresize, imsave, fromimage, toimage

from scipy.optimize import fmin_l_bfgs_b
import time
import argparse
import warnings

from keras.models import Model
from keras.layers import Input
from keras.layers.convolutional import Convolution2D, AveragePooling2D, MaxPooling2D
from keras.utils.data_utils import get_file
from keras.utils.layer_utils import convert_all_kernels_in_model
# Out:
# Using TensorFlow backend.
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (4.0.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow) (0.46)

# %% [markdown]
# ## Utils
#
# ### String to boolean converter

# %%
#String to boolean converter
def str_to_bool(v):
    return v.lower() in ("true", "yes", "t", "1")

# %% [markdown]
# ##Variables

# %%
img_width = 0
img_height = 0
img_WIDTH = 0
img_HEIGHT = 0
aspect_ratio = 0

THEANO_WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_th_dim_ordering_th_kernels_notop.h5'
TF_WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'
TH_19_WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_th_dim_ordering_th_kernels_notop.h5'
TF_19_WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5'


result_prefix = 'res_'

#style_masks_present = args.style_masks is not None
#mask_paths = []

#if style_masks_present:
#    for mask_path in args.style_masks:
#        mask_paths.append(mask_path)

#if style_masks_present:
#    assert len(style_image_paths) == len(mask_paths), "Wrong number of style masks provided.\n" \
#                                                      "Number of style images = %d, \n" \
#                                                      "Number of style mask paths = %d." % \
#                                                      (len(style_image_paths), len(style_masks_present))

#content_mask_present = args.content_mask is not None
#content_mask_path = args.content_mask


#color_mask_present = args.color_mask is not None

# Default value
rescale_image = str_to_bool("False")
#maintain_aspect_ratio = str_to_bool(args.maintain_aspect_ratio)

# Default value
preserve_color = str_to_bool("False")

#these are the weights of the different loss components

#CONTENT WEIGHT
content_weight = 0.025 #default value
total_variation_weight = 8.5e-5 #default value
#total_variation_weight = args.tv_weight


#This array must be just of one position because we are not accepting more than
#one style images. It should be multiplied by the style_scale
style_weights = [1]

# %% [markdown]
# ## Upload Images
# To study how the network works, upload 2 images...

# %%
def upload_files():
  from google.colab import files
  uploaded = files.upload()
  for k, v in uploaded.items():
    open(k, 'wb').write(v)
  return list(uploaded.keys())

print("Upload the Content Image")
imageContent = upload_files()[0]
print(imageContent)

print("Upload the Style Image")
imageStyle = upload_files()[0]
# Out:
# Upload the Content Image
#      <input type="file" id="files-d93f61d2-075a-49ff-aae4-df1afa045d18" name="files[]" multiple disabled />
#      <output id="result-d93f61d2-075a-49ff-aae4-df1afa045d18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1509291534361.43.jpg to 1509291534361.43.jpg
# 1509291534361.43.jpg
# Upload the Style Image
#      <input type="file" id="files-bb554958-6326-43aa-a4d6-99e429c4ef2f" name="files[]" multiple disabled />
#      <output id="result-bb554958-6326-43aa-a4d6-99e429c4ef2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 5027969222d1df2951a62d3d0dae30fa-d8561g8.png to 5027969222d1df2951a62d3d0dae30fa-d8561g8.png

# %% [markdown]
# ... and display them:

# %%
print("-----------------------------------")
print()
print("Content Image")
display(Image(imageContent, width=500))
print()
print("Style Image")
display(Image(imageStyle, width=500))
# Out:
# -----------------------------------
#
# Content Image
# Style Image

# %% [markdown]
# ## Image Preprocessing
#
# Both images are preprocessed and the main parameters of the content image are saved to be used later since the style image will be resized to fit the content image and not otherwise.

# %%
global img_width, img_height, img_WIDTH, img_HEIGHT, aspect_ratio

imgContent = imread(imageContent, mode="RGB")  # Prevents crashes due to PNG images (ARGB)
imgStyle = imread(imageStyle, mode="RGB")  # Prevents crashes due to PNG images (ARGB)

#Saving Content image parameters
img_WIDTH = imgContent.shape[0]
img_HEIGHT = imgContent.shape[1]

print('Original sizes')
print(img_WIDTH)
print(img_HEIGHT)

aspect_ratio = float(img_HEIGHT) / img_WIDTH
img_width = 150    # Minimum image size: 400
img_height = int(img_width * aspect_ratio)

print('Modified sizes')
print(img_width)
print(img_height)

#Image resizing (style image resized to content image size)
imgContent = imresize(imgContent, (img_width, img_height)).astype('float32')
imgStyle = imresize(imgStyle, (img_width, img_height)).astype('float32')

# RGB -> BGR for content image
imgContent = imgContent[:, :, ::-1]
imgContent[:, :, 0] -= 103.939
imgContent[:, :, 1] -= 116.779
imgContent[:, :, 2] -= 123.68

# RGB -> BGR for style image
imgStyle = imgStyle[:, :, ::-1]
imgStyle[:, :, 0] -= 103.939
imgStyle[:, :, 1] -= 116.779
imgStyle[:, :, 2] -= 123.68

if K.image_dim_ordering() == "th":
    imgContent = imgContent.transpose((2, 0, 1)).astype('float32')
    imgStyle = imgStyle.transpose((2, 0, 1)).astype('float32')


imgContent = np.expand_dims(imgContent, axis=0)
imgStyle = np.expand_dims(imgStyle, axis=0)
# Out:
# Original sizes
# 720
# 1080
# Modified sizes
# 150
# 225
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %% [markdown]
#   ## Image to tensor
#
#   Both images are converted to tensor to be used in further steps.

# %%
content_image = K.variable(imgContent)
style_image = K.variable(imgStyle)

# this will contain our generated image
if K.image_dim_ordering() == 'th':
    combination_image = K.placeholder((1, 3, img_width, img_height))
else:
    combination_image = K.placeholder((1, img_width, img_height, 3))

image_tensors = [content_image]
image_tensors.append(style_image)
image_tensors.append(combination_image)

nb_tensors = len(image_tensors)
nb_style_images = nb_tensors - 2 # Content and Output image not considered

# combine the various images into a single Keras tensor
input_tensor = K.concatenate(image_tensors, axis=0)

if K.image_dim_ordering() == "th":
    shape = (nb_tensors, 3, img_width, img_height)
else:
    shape = (nb_tensors, img_width, img_height, 3)

ip = Input(tensor=input_tensor, batch_shape=shape)

# %% [markdown]
# ## Network Structure
#
# ### VGG16 --> FINALLY WE USE VGG19!
#
# We will be using an already trained Convolutional Network (also known as ConvNet), i.e. VGG16 as shown in the next figure:
#
# ![VGG16](http://jesusutrera.com/articles/img/vgg_model.png)
#
# As it can be seen... **(explain VGG16)**
#
# Can use AveragePooling2D inplace of MaxPooling2D layers The original paper uses AveragePooling for better results, but this can be changed to use MaxPooling2D layers via the argument --pool_type="max". By default MaxPooling is used, since if offers sharper images, but AveragePooling applies the style better in some cases (especially when style image is the "Starry Night" by Van Gogh).

# %% [markdown]
# ### The code

# %%
# build the VGG16 network with our 3 images as input
x = Convolution2D(64, (3, 3), activation='relu', name='conv1_1', padding='same')(ip)
x = Convolution2D(64, (3, 3), activation='relu', name='conv1_2', padding='same')(x)
# Average Pooling can also be used with: x = AveragePooling2D((2, 2), strides=(2, 2))(x) in all layers
x = MaxPooling2D((2, 2), strides=(2, 2))(x)
#x = AveragePooling2D((2, 2), strides=(2, 2))(x)

x = Convolution2D(128, (3, 3), activation='relu', name='conv2_1', padding='same')(x)
x = Convolution2D(128, (3, 3), activation='relu', name='conv2_2', padding='same')(x)
x = MaxPooling2D((2, 2), strides=(2, 2))(x)

x = Convolution2D(256, (3, 3), activation='relu', name='conv3_1', padding='same')(x)
x = Convolution2D(256, (3, 3), activation='relu', name='conv3_2', padding='same')(x)
x = Convolution2D(256, (3, 3), activation='relu', name='conv3_3', padding='same')(x)
# For VGG19 uncomment nextline
x = Convolution2D(256, (3, 3), activation='relu', name='conv3_4', padding='same')(x)
x = MaxPooling2D((2, 2), strides=(2, 2))(x)

x = Convolution2D(512, (3, 3), activation='relu', name='conv4_1', padding='same')(x)
x = Convolution2D(512, (3, 3), activation='relu', name='conv4_2', padding='same')(x)
x = Convolution2D(512, (3, 3), activation='relu', name='conv4_3', padding='same')(x)
# For VGG19 uncomment nextline
x = Convolution2D(512, (3, 3), activation='relu', name='conv4_4', padding='same')(x)
x = MaxPooling2D((2, 2), strides=(2, 2))(x)
#x = AveragePooling2D((2, 2), strides=(2, 2))(x)


x = Convolution2D(512, (3, 3), activation='relu', name='conv5_1', padding='same')(x)
x = Convolution2D(512, (3, 3), activation='relu', name='conv5_2', padding='same')(x)
x = Convolution2D(512, (3, 3), activation='relu', name='conv5_3', padding='same')(x)
# For VGG19 uncomment nextline
x = Convolution2D(512, (3, 3), activation='relu', name='conv5_4', padding='same')(x)
x = MaxPooling2D((2, 2), strides=(2, 2))(x)
#x = AveragePooling2D((2, 2), strides=(2, 2))(x)

    
model = Model(ip, x)

# %% [markdown]
# ### Download the pretrained model
#
# Since pretraining a model could take hours, we just download the pretrained model weights in order to speed up the process.

# %%
if K.image_dim_ordering() == "th":
  weights = get_file('vgg19_weights_th_dim_ordering_th_kernels_notop.h5', TH_19_WEIGHTS_PATH_NO_TOP, cache_subdir='models')
  #weights = get_file('vgg16_weights_th_dim_ordering_th_kernels_notop.h5', THEANO_WEIGHTS_PATH_NO_TOP, cache_subdir='models')

else:
  weights = get_file('vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5', TF_19_WEIGHTS_PATH_NO_TOP, cache_subdir='models')
  #weights = get_file('vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5', TF_WEIGHTS_PATH_NO_TOP, cache_subdir='models')

model.load_weights(weights)

if K.backend() == 'tensorflow' and K.image_dim_ordering() == "th":
    warnings.warn('You are using the TensorFlow backend, yet you '
                  'are using the Theano '
                  'image dimension ordering convention '
                  '(`image_dim_ordering="th"`). '
                  'For best performance, set '
                  '`image_dim_ordering="tf"` in '
                  'your Keras config '
                  'at ~/.keras/keras.json.')
    convert_all_kernels_in_model(model)

print('Model loaded.')

# get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
shape_dict = dict([(layer.name, layer.output_shape) for layer in model.layers])
print(shape_dict)
# Out:
# Model loaded.
# {'input_5': (3, 150, 225, 3), 'conv1_1': (3, 150, 225, 64), 'conv1_2': (3, 150, 225, 64), 'max_pooling2d_21': (3, 75, 112, 64), 'conv2_1': (3, 75, 112, 128), 'conv2_2': (3, 75, 112, 128), 'max_pooling2d_22': (3, 37, 56, 128), 'conv3_1': (3, 37, 56, 256), 'conv3_2': (3, 37, 56, 256), 'conv3_3': (3, 37, 56, 256), 'conv3_4': (3, 37, 56, 256), 'max_pooling2d_23': (3, 18, 28, 256), 'conv4_1': (3, 18, 28, 512), 'conv4_2': (3, 18, 28, 512), 'conv4_3': (3, 18, 28, 512), 'conv4_4': (3, 18, 28, 512), 'max_pooling2d_24': (3, 9, 14, 512), 'conv5_1': (3, 9, 14, 512), 'conv5_2': (3, 9, 14, 512), 'conv5_3': (3, 9, 14, 512), 'conv5_4': (3, 9, 14, 512), 'max_pooling2d_25': (3, 4, 7, 512)}

# %% [markdown]
# ## Loss

# %% [markdown]
# ### Content Loss
#
# It is defined as the mean squared error of difference between feature map representation (values of hidden activations) of the content image (P_l) and feature map representation of the generated image (F_l) at hidden layer (l)

# %%
# an auxiliary loss function
# designed to maintain the "content" of the
# base image in the generated image
def content_loss(base, combination):
    channel_dim = 0 if K.image_dim_ordering() == "th" else -1

    try:
        channels = K.int_shape(base)[channel_dim]
    except TypeError:
        channels = K.shape(base)[channel_dim]
    size = img_width * img_height
    
    #By default the type of content loss is 0: 
    multiplier = 1.
    #... but it can be one of the following:
    # type 2 -> multiplier = 1. / (channels * size)
    # type 1 -> 
    #multiplier = 1. / (2. * (channels ** 0.5) * (size ** 0.5))

    return multiplier * K.sum(K.square(combination - base))

# %% [markdown]
# ### Style Loss
#
# It is defined as mean squared error between the Gram Matrix representations for the style image (A_l) and the generated image (G_l) respectively in layer (l). Since we have defined our style through the combination of multiple layers, we would sum up the square of the difference for each layer (l). Please note that N and M stands for the size of the height and width of the style image

# %%
# the "style loss" is designed to maintain
# the style of the reference image in the generated image.
# It is based on the gram matrices (which capture style) of
# feature maps from the style reference image
# and from the generated image
def style_loss(style, combination, mask_path=None, nb_channels=None):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_width * img_height
    return K.sum(K.square(C - S)) / (4. * (channels ** 2) * (size ** 2))

# %% [markdown]
# ### Gram Matrix
#
# It is only used in style loss computation.

# %%
#Gram matrix of an image tensor (feature-wise outer product)
def gram_matrix(x):
    assert K.ndim(x) == 3
    if K.image_dim_ordering() == "th":
        features = K.batch_flatten(x)
    else:
        features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %% [markdown]
# ### Loss computation

# %%
# combine these loss functions into a single scalar
loss = K.variable(0.)
layer_features = outputs_dict["conv4_2"]  # 'conv5_2' or 'conv4_2'
print(layer_features)
base_image_features = layer_features[0, :, :, :] #Extracts values from the content image (0)
combination_features = layer_features[nb_tensors - 1, :, :, :] #Extracts values from the combination image (nb_tensors-1=2)

print("Computing content loss w/ weight =", content_weight)
loss = loss + content_weight * content_loss(base_image_features,combination_features)
print("-------------------------------------")
print()


channel_index = 1 if K.image_dim_ordering() == "th" else -1

feature_layers = ['conv1_1', 'conv2_1', 'conv3_1', 'conv4_1', 'conv5_1']
for layer_name in feature_layers:
    print("Extracting features from layer", layer_name)
    layer_features = outputs_dict[layer_name]
    shape = shape_dict[layer_name]
    combination_features = layer_features[nb_tensors - 1, :, :, :]
    style_reference_features = layer_features[1:nb_tensors - 1, :, :, :]
    sl = []
    
    for j in range(nb_style_images):
        print("  -   Style_reference_features:",style_reference_features[j])
        sl.append(style_loss(style_reference_features[j], combination_features, None, shape))        

    for j in range(nb_style_images):
        print("  -   Computing style loss w/ weight =", style_weights[j])
        loss = loss + (style_weights[j] / len(feature_layers)) * sl[j]
        print("  -   SL(j) - ", sl[j])
        print()

if K.image_dim_ordering() == 'th':
    a = K.square(combination_image[:, :, :img_width - 1, :img_height - 1] - combination_image[:, :, 1:, :img_height - 1])
    b = K.square(combination_image[:, :, :img_width - 1, :img_height - 1] - combination_image[:, :, :img_width - 1, 1:])
else:
    a = K.square(combination_image[:, :img_width - 1, :img_height - 1, :] - combination_image[:, 1:, :img_height - 1, :])
    b = K.square(combination_image[:, :img_width - 1, :img_height - 1, :] - combination_image[:, :img_width - 1, 1:, :])
t_variation = K.sum(K.pow(a + b, 1.25))

loss = loss + total_variation_weight * t_variation

# get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)

outputs = [loss]
if type(grads) in {list, tuple}:
    outputs += grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image], outputs)
# Out:
# Tensor("conv4_2_4/Relu:0", shape=(3, 18, 28, 512), dtype=float32)
# Computing content loss w/ weight = 0.025
# -------------------------------------
#
# Extracting features from layer conv1_1
#   -   Style_reference_features: Tensor("strided_slice_438:0", shape=(150, 225, 64), dtype=float32)
#   -   Computing style loss w/ weight = 5
#   -   SL(j) -  Tensor("truediv_60:0", shape=(), dtype=float32)
#
# Extracting features from layer conv2_1
#   -   Style_reference_features: Tensor("strided_slice_444:0", shape=(75, 112, 128), dtype=float32)
#   -   Computing style loss w/ weight = 5
#   -   SL(j) -  Tensor("truediv_61:0", shape=(), dtype=float32)
#
# Extracting features from layer conv3_1
#   -   Style_reference_features: Tensor("strided_slice_450:0", shape=(37, 56, 256), dtype=float32)
#   -   Computing style loss w/ weight = 5
#   -   SL(j) -  Tensor("truediv_62:0", shape=(), dtype=float32)
#
# Extracting features from layer conv4_1
#   -   Style_reference_features: Tensor("strided_slice_456:0", shape=(18, 28, 512), dtype=float32)
#   -   Computing style loss w/ weight = 5
#   -   SL(j) -  Tensor("truediv_63:0", shape=(), dtype=float32)
#
# Extracting features from layer conv5_1
#   -   Style_reference_features: Tensor("strided_slice_462:0", shape=(9, 14, 512), dtype=float32)
#   -   Computing style loss w/ weight = 5
#   -   SL(j) -  Tensor("truediv_64:0", shape=(), dtype=float32)

# %% [markdown]
# ##Evaluation
# ### Evaluate loss and grad

# %%
def eval_loss_and_grads(x):
    if K.image_dim_ordering() == 'th':
        x = x.reshape((1, 3, img_width, img_height))
    else:
        x = x.reshape((1, img_width, img_height, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# %% [markdown]
# ### Evaluation

# %%
# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.
class Evaluator(object):
    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values
      
evaluator = Evaluator()

# %%
def eval_loss_and_grads(x):
    if K.image_dim_ordering() == 'th':
        x = x.reshape((1, 3, img_width, img_height))
    else:
        x = x.reshape((1, img_width, img_height, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.
class Evaluator(object):
    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values
      
evaluator = Evaluator()

# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss

# By default, init_image = "content". If it was gray, it would be the same.
x = imgContent

# If init_image = "noise":
#x = np.random.uniform(0, 255, (1, img_width, img_height, 3)) - 128.
#if K.image_dim_ordering() == "th":
#  x = x.transpose((0, 3, 1, 2))

# Default color = false
color_mask = None

# Default value num_iter 10
num_iter = 500
prev_min_val = -1

# Default value min_improvement = 0.0. Defines minimum improvement required to continue the script
improvement_threshold = float(0.0)

for i in range(num_iter):
    print("Starting iteration %d of %d" % ((i + 1), num_iter))
    start_time = time.time()
    

    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(), fprime=evaluator.grads, maxfun=20)
    print("Evaluator loss",evaluator.loss)
    if prev_min_val == -1:
        prev_min_val = min_val

    improvement = (prev_min_val - min_val) / prev_min_val * 100

    print('Current loss value:', min_val, " Improvement : %0.3f" % improvement, "%")
    prev_min_val = min_val
    
    #----------------------
    # Deprocess image
    # save current generated image
    x_copy = x.copy()    
    if K.image_dim_ordering() == "th":
        x_copy = x_copy.reshape((3, img_width, img_height))
        x_copy = x_copy.transpose((1, 2, 0))
    else:
        x_copy = x_copy.reshape((img_width, img_height, 3))

    x_copy[:, :, 0] += 103.939
    x_copy[:, :, 1] += 116.779
    x_copy[:, :, 2] += 123.68

    # BGR -> RGB
    x_copy = x_copy[:, :, ::-1]

    img = np.clip(x_copy, 0, 255).astype('uint8')
    #----------------------

    if preserve_color and content is not None:
        img = original_color_transform(content, img, mask=color_mask)

    if not rescale_image:
        img_ht = int(img_width * aspect_ratio)
        print("Rescaling Image to (%d, %d)" % (img_width, img_ht))
        img = imresize(img, (img_width, img_ht), interp="bilinear") #Default value

    if rescale_image:
        print("Rescaling Image to (%d, %d)" % (img_WIDTH, img_HEIGHT))
        img = imresize(img, (img_WIDTH, img_HEIGHT), interp="bilinear") #Default value

    fname = result_prefix + 'at_iteration_%d.png' % (i + 1)
    imsave(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i + 1, end_time - start_time))
    if i in range(0,10) or i == num_iter-1:
      display(Image(fname, width=500))

    if improvement_threshold is not 0.0:
        if improvement < improvement_threshold and improvement is not 0.0:
            print("Improvement (%f) is less than improvement threshold (%f). Early stopping script." % (
                improvement, improvement_threshold))
            exit()
# Out:
# Starting iteration 1 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 20181617000.0  Improvement : 0.000 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_1.png
# Iteration 1 completed in 3s
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:103: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:110: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# Starting iteration 2 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 11602304000.0  Improvement : 42.511 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_2.png
# Iteration 2 completed in 2s
# Starting iteration 3 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 9113781000.0  Improvement : 21.449 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_3.png
# Iteration 3 completed in 2s
# Starting iteration 4 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 7970919000.0  Improvement : 12.540 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_4.png
# Iteration 4 completed in 2s
# Starting iteration 5 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 7119776300.0  Improvement : 10.678 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_5.png
# Iteration 5 completed in 2s
# Starting iteration 6 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 6659910000.0  Improvement : 6.459 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_6.png
# Iteration 6 completed in 2s
# Starting iteration 7 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 6319048000.0  Improvement : 5.118 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_7.png
# Iteration 7 completed in 2s
# Starting iteration 8 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 6091007500.0  Improvement : 3.609 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_8.png
# Iteration 8 completed in 2s
# Starting iteration 9 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5908409000.0  Improvement : 2.998 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_9.png
# Iteration 9 completed in 2s
# Starting iteration 10 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5765689300.0  Improvement : 2.416 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_10.png
# Iteration 10 completed in 2s
# Starting iteration 11 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5637018600.0  Improvement : 2.232 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_11.png
# Iteration 11 completed in 2s
# Starting iteration 12 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5551037000.0  Improvement : 1.525 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_12.png
# Iteration 12 completed in 2s
# Starting iteration 13 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5468105700.0  Improvement : 1.494 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_13.png
# Iteration 13 completed in 2s
# Starting iteration 14 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5392880000.0  Improvement : 1.376 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_14.png
# Iteration 14 completed in 2s
# Starting iteration 15 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5324264000.0  Improvement : 1.272 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_15.png
# Iteration 15 completed in 2s
# Starting iteration 16 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5268286000.0  Improvement : 1.051 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_16.png
# Iteration 16 completed in 2s
# Starting iteration 17 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5217569000.0  Improvement : 0.963 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_17.png
# Iteration 17 completed in 2s
# Starting iteration 18 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5172800000.0  Improvement : 0.858 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_18.png
# Iteration 18 completed in 2s
# Starting iteration 19 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5120424000.0  Improvement : 1.013 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_19.png
# Iteration 19 completed in 2s
# Starting iteration 20 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5074380300.0  Improvement : 0.899 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_20.png
# Iteration 20 completed in 2s
# Starting iteration 21 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 5033450000.0  Improvement : 0.807 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_21.png
# Iteration 21 completed in 2s
# Starting iteration 22 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4994151400.0  Improvement : 0.781 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_22.png
# Iteration 22 completed in 2s
# Starting iteration 23 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4960269000.0  Improvement : 0.678 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_23.png
# Iteration 23 completed in 2s
# Starting iteration 24 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4930045400.0  Improvement : 0.609 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_24.png
# Iteration 24 completed in 2s
# Starting iteration 25 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4891747000.0  Improvement : 0.777 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_25.png
# Iteration 25 completed in 2s
# Starting iteration 26 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4857455600.0  Improvement : 0.701 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_26.png
# Iteration 26 completed in 2s
# Starting iteration 27 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4834707000.0  Improvement : 0.468 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_27.png
# Iteration 27 completed in 2s
# Starting iteration 28 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4810949000.0  Improvement : 0.491 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_28.png
# Iteration 28 completed in 2s
# Starting iteration 29 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4788760000.0  Improvement : 0.461 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_29.png
# Iteration 29 completed in 2s
# Starting iteration 30 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4769035300.0  Improvement : 0.412 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_30.png
# Iteration 30 completed in 2s
# Starting iteration 31 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4751744000.0  Improvement : 0.363 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_31.png
# Iteration 31 completed in 2s
# Starting iteration 32 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4731775500.0  Improvement : 0.420 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_32.png
# Iteration 32 completed in 2s
# Starting iteration 33 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4714712600.0  Improvement : 0.361 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_33.png
# Iteration 33 completed in 2s
# Starting iteration 34 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4696336000.0  Improvement : 0.390 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_34.png
# Iteration 34 completed in 2s
# Starting iteration 35 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4680492000.0  Improvement : 0.337 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_35.png
# Iteration 35 completed in 2s
# Starting iteration 36 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4666338000.0  Improvement : 0.302 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_36.png
# Iteration 36 completed in 2s
# Starting iteration 37 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4654519000.0  Improvement : 0.253 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_37.png
# Iteration 37 completed in 2s
# Starting iteration 38 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4641395700.0  Improvement : 0.282 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_38.png
# Iteration 38 completed in 2s
# Starting iteration 39 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4627624000.0  Improvement : 0.297 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_39.png
# Iteration 39 completed in 2s
# Starting iteration 40 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4615511000.0  Improvement : 0.262 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_40.png
# Iteration 40 completed in 2s
# Starting iteration 41 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4598149600.0  Improvement : 0.376 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_41.png
# Iteration 41 completed in 2s
# Starting iteration 42 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4584517600.0  Improvement : 0.296 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_42.png
# Iteration 42 completed in 2s
# Starting iteration 43 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4572865000.0  Improvement : 0.254 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_43.png
# Iteration 43 completed in 2s
# Starting iteration 44 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4562151000.0  Improvement : 0.234 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_44.png
# Iteration 44 completed in 2s
# Starting iteration 45 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4552203000.0  Improvement : 0.218 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_45.png
# Iteration 45 completed in 2s
# Starting iteration 46 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4539120000.0  Improvement : 0.287 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_46.png
# Iteration 46 completed in 2s
# Starting iteration 47 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4528442000.0  Improvement : 0.235 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_47.png
# Iteration 47 completed in 2s
# Starting iteration 48 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4515172400.0  Improvement : 0.293 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_48.png
# Iteration 48 completed in 2s
# Starting iteration 49 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4503898600.0  Improvement : 0.250 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_49.png
# Iteration 49 completed in 2s
# Starting iteration 50 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4495117300.0  Improvement : 0.195 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_50.png
# Iteration 50 completed in 2s
# Starting iteration 51 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4485494300.0  Improvement : 0.214 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_51.png
# Iteration 51 completed in 2s
# Starting iteration 52 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4475586600.0  Improvement : 0.221 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_52.png
# Iteration 52 completed in 2s
# Starting iteration 53 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4465550300.0  Improvement : 0.224 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_53.png
# Iteration 53 completed in 2s
# Starting iteration 54 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4457687600.0  Improvement : 0.176 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_54.png
# Iteration 54 completed in 2s
# Starting iteration 55 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4449670700.0  Improvement : 0.180 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_55.png
# Iteration 55 completed in 2s
# Starting iteration 56 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4442448000.0  Improvement : 0.162 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_56.png
# Iteration 56 completed in 2s
# Starting iteration 57 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4435283000.0  Improvement : 0.161 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_57.png
# Iteration 57 completed in 2s
# Starting iteration 58 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4426506000.0  Improvement : 0.198 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_58.png
# Iteration 58 completed in 2s
# Starting iteration 59 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4418355000.0  Improvement : 0.184 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_59.png
# Iteration 59 completed in 2s
# Starting iteration 60 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4408974300.0  Improvement : 0.212 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_60.png
# Iteration 60 completed in 2s
# Starting iteration 61 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4400186000.0  Improvement : 0.199 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_61.png
# Iteration 61 completed in 2s
# Starting iteration 62 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4394089000.0  Improvement : 0.139 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_62.png
# Iteration 62 completed in 2s
# Starting iteration 63 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4388291000.0  Improvement : 0.132 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_63.png
# Iteration 63 completed in 2s
# Starting iteration 64 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4383548000.0  Improvement : 0.108 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_64.png
# Iteration 64 completed in 2s
# Starting iteration 65 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4378185700.0  Improvement : 0.122 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_65.png
# Iteration 65 completed in 2s
# Starting iteration 66 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4373343000.0  Improvement : 0.111 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_66.png
# Iteration 66 completed in 2s
# Starting iteration 67 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4368703000.0  Improvement : 0.106 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_67.png
# Iteration 67 completed in 2s
# Starting iteration 68 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4363958000.0  Improvement : 0.109 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_68.png
# Iteration 68 completed in 2s
# Starting iteration 69 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4359466000.0  Improvement : 0.103 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_69.png
# Iteration 69 completed in 2s
# Starting iteration 70 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4354550300.0  Improvement : 0.113 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_70.png
# Iteration 70 completed in 2s
# Starting iteration 71 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4346651600.0  Improvement : 0.181 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_71.png
# Iteration 71 completed in 2s
# Starting iteration 72 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4337310000.0  Improvement : 0.215 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_72.png
# Iteration 72 completed in 2s
# Starting iteration 73 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4331007000.0  Improvement : 0.145 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_73.png
# Iteration 73 completed in 2s
# Starting iteration 74 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4325641700.0  Improvement : 0.124 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_74.png
# Iteration 74 completed in 2s
# Starting iteration 75 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4321357300.0  Improvement : 0.099 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_75.png
# Iteration 75 completed in 2s
# Starting iteration 76 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4317541000.0  Improvement : 0.088 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_76.png
# Iteration 76 completed in 2s
# Starting iteration 77 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4314203600.0  Improvement : 0.077 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_77.png
# Iteration 77 completed in 2s
# Starting iteration 78 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4310895600.0  Improvement : 0.077 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_78.png
# Iteration 78 completed in 2s
# Starting iteration 79 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4307782000.0  Improvement : 0.072 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_79.png
# Iteration 79 completed in 2s
# Starting iteration 80 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4304467500.0  Improvement : 0.077 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_80.png
# Iteration 80 completed in 2s
# Starting iteration 81 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4300899000.0  Improvement : 0.083 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_81.png
# Iteration 81 completed in 2s
# Starting iteration 82 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4297664500.0  Improvement : 0.075 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_82.png
# Iteration 82 completed in 2s
# Starting iteration 83 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4294672600.0  Improvement : 0.070 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_83.png
# Iteration 83 completed in 2s
# Starting iteration 84 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4291729000.0  Improvement : 0.069 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_84.png
# Iteration 84 completed in 2s
# Starting iteration 85 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4288486000.0  Improvement : 0.076 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_85.png
# Iteration 85 completed in 2s
# Starting iteration 86 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4285234200.0  Improvement : 0.076 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_86.png
# Iteration 86 completed in 2s
# Starting iteration 87 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4281392600.0  Improvement : 0.090 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_87.png
# Iteration 87 completed in 2s
# Starting iteration 88 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4277968600.0  Improvement : 0.080 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_88.png
# Iteration 88 completed in 2s
# Starting iteration 89 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4274195700.0  Improvement : 0.088 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_89.png
# Iteration 89 completed in 2s
# Starting iteration 90 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4271379000.0  Improvement : 0.066 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_90.png
# Iteration 90 completed in 2s
# Starting iteration 91 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4268653300.0  Improvement : 0.064 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_91.png
# Iteration 91 completed in 2s
# Starting iteration 92 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4266070500.0  Improvement : 0.061 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_92.png
# Iteration 92 completed in 2s
# Starting iteration 93 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4263360300.0  Improvement : 0.064 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_93.png
# Iteration 93 completed in 2s
# Starting iteration 94 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4261064200.0  Improvement : 0.054 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_94.png
# Iteration 94 completed in 2s
# Starting iteration 95 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4258222800.0  Improvement : 0.067 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_95.png
# Iteration 95 completed in 2s
# Starting iteration 96 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4255840500.0  Improvement : 0.056 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_96.png
# Iteration 96 completed in 2s
# Starting iteration 97 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4253390300.0  Improvement : 0.058 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_97.png
# Iteration 97 completed in 2s
# Starting iteration 98 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4251070700.0  Improvement : 0.055 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_98.png
# Iteration 98 completed in 2s
# Starting iteration 99 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4248735500.0  Improvement : 0.055 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_99.png
# Iteration 99 completed in 2s
# Starting iteration 100 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4246382300.0  Improvement : 0.055 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_100.png
# Iteration 100 completed in 2s
# Starting iteration 101 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4244114200.0  Improvement : 0.053 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_101.png
# Iteration 101 completed in 2s
# Starting iteration 102 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4241477600.0  Improvement : 0.062 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_102.png
# Iteration 102 completed in 2s
# Starting iteration 103 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4238791400.0  Improvement : 0.063 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_103.png
# Iteration 103 completed in 2s
# Starting iteration 104 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4236712000.0  Improvement : 0.049 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_104.png
# Iteration 104 completed in 2s
# Starting iteration 105 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4234517800.0  Improvement : 0.052 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_105.png
# Iteration 105 completed in 2s
# Starting iteration 106 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4232296000.0  Improvement : 0.052 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_106.png
# Iteration 106 completed in 2s
# Starting iteration 107 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4230099500.0  Improvement : 0.052 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_107.png
# Iteration 107 completed in 2s
# Starting iteration 108 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4227361500.0  Improvement : 0.065 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_108.png
# Iteration 108 completed in 2s
# Starting iteration 109 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4224951600.0  Improvement : 0.057 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_109.png
# Iteration 109 completed in 2s
# Starting iteration 110 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4222993000.0  Improvement : 0.046 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_110.png
# Iteration 110 completed in 2s
# Starting iteration 111 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4220977700.0  Improvement : 0.048 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_111.png
# Iteration 111 completed in 2s
# Starting iteration 112 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4219366700.0  Improvement : 0.038 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_112.png
# Iteration 112 completed in 2s
# Starting iteration 113 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4217689900.0  Improvement : 0.040 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_113.png
# Iteration 113 completed in 2s
# Starting iteration 114 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4216024800.0  Improvement : 0.039 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_114.png
# Iteration 114 completed in 2s
# Starting iteration 115 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4214559500.0  Improvement : 0.035 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_115.png
# Iteration 115 completed in 2s
# Starting iteration 116 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4213027300.0  Improvement : 0.036 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_116.png
# Iteration 116 completed in 2s
# Starting iteration 117 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4211476000.0  Improvement : 0.037 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_117.png
# Iteration 117 completed in 2s
# Starting iteration 118 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4209751300.0  Improvement : 0.041 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_118.png
# Iteration 118 completed in 2s
# Starting iteration 119 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4208298000.0  Improvement : 0.035 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_119.png
# Iteration 119 completed in 2s
# Starting iteration 120 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4206423800.0  Improvement : 0.045 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_120.png
# Iteration 120 completed in 2s
# Starting iteration 121 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4204725200.0  Improvement : 0.040 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_121.png
# Iteration 121 completed in 2s
# Starting iteration 122 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4203029000.0  Improvement : 0.040 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_122.png
# Iteration 122 completed in 2s
# Starting iteration 123 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4201340700.0  Improvement : 0.040 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_123.png
# Iteration 123 completed in 2s
# Starting iteration 124 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4199953000.0  Improvement : 0.033 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_124.png
# Iteration 124 completed in 2s
# Starting iteration 125 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4198370600.0  Improvement : 0.038 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_125.png
# Iteration 125 completed in 2s
# Starting iteration 126 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4196828700.0  Improvement : 0.037 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_126.png
# Iteration 126 completed in 2s
# Starting iteration 127 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4195360000.0  Improvement : 0.035 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_127.png
# Iteration 127 completed in 2s
# Starting iteration 128 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4193431300.0  Improvement : 0.046 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_128.png
# Iteration 128 completed in 2s
# Starting iteration 129 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4191676400.0  Improvement : 0.042 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_129.png
# Iteration 129 completed in 2s
# Starting iteration 130 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4189573000.0  Improvement : 0.050 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_130.png
# Iteration 130 completed in 2s
# Starting iteration 131 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4188173300.0  Improvement : 0.033 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_131.png
# Iteration 131 completed in 2s
# Starting iteration 132 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4186712000.0  Improvement : 0.035 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_132.png
# Iteration 132 completed in 2s
# Starting iteration 133 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4184964000.0  Improvement : 0.042 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_133.png
# Iteration 133 completed in 2s
# Starting iteration 134 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4183294500.0  Improvement : 0.040 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_134.png
# Iteration 134 completed in 2s
# Starting iteration 135 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4181996800.0  Improvement : 0.031 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_135.png
# Iteration 135 completed in 2s
# Starting iteration 136 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4180590000.0  Improvement : 0.034 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_136.png
# Iteration 136 completed in 2s
# Starting iteration 137 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4179193000.0  Improvement : 0.033 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_137.png
# Iteration 137 completed in 2s
# Starting iteration 138 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4177571300.0  Improvement : 0.039 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_138.png
# Iteration 138 completed in 2s
# Starting iteration 139 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4176137000.0  Improvement : 0.034 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_139.png
# Iteration 139 completed in 2s
# Starting iteration 140 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4174675500.0  Improvement : 0.035 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_140.png
# Iteration 140 completed in 2s
# Starting iteration 141 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4173006600.0  Improvement : 0.040 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_141.png
# Iteration 141 completed in 2s
# Starting iteration 142 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4171639600.0  Improvement : 0.033 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_142.png
# Iteration 142 completed in 2s
# Starting iteration 143 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4170502000.0  Improvement : 0.027 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_143.png
# Iteration 143 completed in 2s
# Starting iteration 144 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4169370400.0  Improvement : 0.027 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_144.png
# Iteration 144 completed in 2s
# Starting iteration 145 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4167790800.0  Improvement : 0.038 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_145.png
# Iteration 145 completed in 2s
# Starting iteration 146 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4165888500.0  Improvement : 0.046 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_146.png
# Iteration 146 completed in 2s
# Starting iteration 147 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4164796700.0  Improvement : 0.026 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_147.png
# Iteration 147 completed in 2s
# Starting iteration 148 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4163815700.0  Improvement : 0.024 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_148.png
# Iteration 148 completed in 2s
# Starting iteration 149 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4162577700.0  Improvement : 0.030 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_149.png
# Iteration 149 completed in 2s
# Starting iteration 150 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4161277700.0  Improvement : 0.031 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_150.png
# Iteration 150 completed in 2s
# Starting iteration 151 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4160144600.0  Improvement : 0.027 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_151.png
# Iteration 151 completed in 2s
# Starting iteration 152 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4159171000.0  Improvement : 0.023 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_152.png
# Iteration 152 completed in 2s
# Starting iteration 153 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4158204000.0  Improvement : 0.023 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_153.png
# Iteration 153 completed in 2s
# Starting iteration 154 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4157287700.0  Improvement : 0.022 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_154.png
# Iteration 154 completed in 2s
# Starting iteration 155 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4156069400.0  Improvement : 0.029 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_155.png
# Iteration 155 completed in 2s
# Starting iteration 156 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4155107000.0  Improvement : 0.023 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_156.png
# Iteration 156 completed in 2s
# Starting iteration 157 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4154055200.0  Improvement : 0.025 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_157.png
# Iteration 157 completed in 2s
# Starting iteration 158 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4152737000.0  Improvement : 0.032 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_158.png
# Iteration 158 completed in 2s
# Starting iteration 159 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4150680600.0  Improvement : 0.050 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_159.png
# Iteration 159 completed in 2s
# Starting iteration 160 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4149542000.0  Improvement : 0.027 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_160.png
# Iteration 160 completed in 2s
# Starting iteration 161 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4148471600.0  Improvement : 0.026 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_161.png
# Iteration 161 completed in 2s
# Starting iteration 162 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4147286300.0  Improvement : 0.029 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_162.png
# Iteration 162 completed in 2s
# Starting iteration 163 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4145984300.0  Improvement : 0.031 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_163.png
# Iteration 163 completed in 2s
# Starting iteration 164 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4145099300.0  Improvement : 0.021 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_164.png
# Iteration 164 completed in 2s
# Starting iteration 165 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4144175000.0  Improvement : 0.022 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_165.png
# Iteration 165 completed in 2s
# Starting iteration 166 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4143359200.0  Improvement : 0.020 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_166.png
# Iteration 166 completed in 2s
# Starting iteration 167 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4142304300.0  Improvement : 0.025 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_167.png
# Iteration 167 completed in 2s
# Starting iteration 168 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4141415700.0  Improvement : 0.021 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_168.png
# Iteration 168 completed in 2s
# Starting iteration 169 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4140621600.0  Improvement : 0.019 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_169.png
# Iteration 169 completed in 2s
# Starting iteration 170 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4139929300.0  Improvement : 0.017 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_170.png
# Iteration 170 completed in 2s
# Starting iteration 171 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4139285000.0  Improvement : 0.016 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_171.png
# Iteration 171 completed in 2s
# ...
# Starting iteration 235 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4093208800.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_235.png
# Iteration 235 completed in 2s
# Starting iteration 236 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4092776700.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_236.png
# Iteration 236 completed in 2s
# Starting iteration 237 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4092389000.0  Improvement : 0.009 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_237.png
# Iteration 237 completed in 2s
# Starting iteration 238 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4091898000.0  Improvement : 0.012 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_238.png
# Iteration 238 completed in 2s
# Starting iteration 239 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4091392500.0  Improvement : 0.012 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_239.png
# Iteration 239 completed in 2s
# Starting iteration 240 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4090897400.0  Improvement : 0.012 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_240.png
# Iteration 240 completed in 2s
# Starting iteration 241 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4090442800.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_241.png
# Iteration 241 completed in 2s
# Starting iteration 242 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4090010400.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_242.png
# Iteration 242 completed in 2s
# Starting iteration 243 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4089457400.0  Improvement : 0.014 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_243.png
# Iteration 243 completed in 2s
# Starting iteration 244 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4088898300.0  Improvement : 0.014 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_244.png
# Iteration 244 completed in 2s
# Starting iteration 245 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4088465700.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_245.png
# Iteration 245 completed in 2s
# Starting iteration 246 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4088002800.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_246.png
# Iteration 246 completed in 2s
# Starting iteration 247 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4087424300.0  Improvement : 0.014 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_247.png
# Iteration 247 completed in 2s
# Starting iteration 248 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4086843100.0  Improvement : 0.014 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_248.png
# Iteration 248 completed in 2s
# Starting iteration 249 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4086465300.0  Improvement : 0.009 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_249.png
# Iteration 249 completed in 2s
# Starting iteration 250 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4086002000.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_250.png
# Iteration 250 completed in 2s
# Starting iteration 251 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4085630500.0  Improvement : 0.009 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_251.png
# Iteration 251 completed in 2s
# Starting iteration 252 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4085295900.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_252.png
# Iteration 252 completed in 2s
# Starting iteration 253 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4084854500.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_253.png
# Iteration 253 completed in 2s
# Starting iteration 254 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4084391400.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_254.png
# Iteration 254 completed in 2s
# Starting iteration 255 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4083912400.0  Improvement : 0.012 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_255.png
# Iteration 255 completed in 2s
# Starting iteration 256 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4083414000.0  Improvement : 0.012 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_256.png
# Iteration 256 completed in 2s
# Starting iteration 257 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4082924000.0  Improvement : 0.012 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_257.png
# Iteration 257 completed in 2s
# Starting iteration 258 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4082420200.0  Improvement : 0.012 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_258.png
# Iteration 258 completed in 2s
# Starting iteration 259 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4082018600.0  Improvement : 0.010 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_259.png
# Iteration 259 completed in 2s
# Starting iteration 260 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4081518000.0  Improvement : 0.012 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_260.png
# Iteration 260 completed in 2s
# Starting iteration 261 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4081130000.0  Improvement : 0.010 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_261.png
# Iteration 261 completed in 2s
# Starting iteration 262 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4080601000.0  Improvement : 0.013 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_262.png
# Iteration 262 completed in 2s
# Starting iteration 263 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4080275500.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_263.png
# Iteration 263 completed in 2s
# Starting iteration 264 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4079941400.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_264.png
# Iteration 264 completed in 2s
# Starting iteration 265 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4079618000.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_265.png
# Iteration 265 completed in 2s
# Starting iteration 266 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4079265500.0  Improvement : 0.009 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_266.png
# Iteration 266 completed in 2s
# Starting iteration 267 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4078922200.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_267.png
# Iteration 267 completed in 2s
# Starting iteration 268 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4078597400.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_268.png
# Iteration 268 completed in 2s
# Starting iteration 269 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4078301200.0  Improvement : 0.007 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_269.png
# Iteration 269 completed in 2s
# Starting iteration 270 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4077974000.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_270.png
# Iteration 270 completed in 2s
# Starting iteration 271 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4077627600.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_271.png
# Iteration 271 completed in 2s
# Starting iteration 272 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4077300500.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_272.png
# Iteration 272 completed in 2s
# Starting iteration 273 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4076970800.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_273.png
# Iteration 273 completed in 2s
# Starting iteration 274 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4076622600.0  Improvement : 0.009 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_274.png
# Iteration 274 completed in 2s
# Starting iteration 275 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4076228000.0  Improvement : 0.010 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_275.png
# Iteration 275 completed in 2s
# Starting iteration 276 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4075840000.0  Improvement : 0.010 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_276.png
# Iteration 276 completed in 2s
# Starting iteration 277 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4075430100.0  Improvement : 0.010 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_277.png
# Iteration 277 completed in 2s
# Starting iteration 278 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4075096000.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_278.png
# Iteration 278 completed in 2s
# Starting iteration 279 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4074724600.0  Improvement : 0.009 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_279.png
# Iteration 279 completed in 2s
# Starting iteration 280 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4074319000.0  Improvement : 0.010 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_280.png
# Iteration 280 completed in 2s
# Starting iteration 281 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4073893600.0  Improvement : 0.010 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_281.png
# Iteration 281 completed in 2s
# Starting iteration 282 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4073496800.0  Improvement : 0.010 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_282.png
# Iteration 282 completed in 2s
# Starting iteration 283 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4073047800.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_283.png
# Iteration 283 completed in 2s
# Starting iteration 284 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4072689200.0  Improvement : 0.009 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_284.png
# Iteration 284 completed in 2s
# Starting iteration 285 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4072347000.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_285.png
# Iteration 285 completed in 2s
# Starting iteration 286 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4072020700.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_286.png
# Iteration 286 completed in 2s
# Starting iteration 287 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4071647200.0  Improvement : 0.009 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_287.png
# Iteration 287 completed in 2s
# Starting iteration 288 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4071245800.0  Improvement : 0.010 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_288.png
# Iteration 288 completed in 2s
# Starting iteration 289 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4070807000.0  Improvement : 0.011 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_289.png
# Iteration 289 completed in 2s
# Starting iteration 290 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4070481700.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_290.png
# Iteration 290 completed in 2s
# Starting iteration 291 of 500
# Evaluator loss <bound method Evaluator.loss of <__main__.Evaluator object at 0x7f0ac9bcda90>>
# Current loss value: 4070141000.0  Improvement : 0.008 %
# Rescaling Image to (150, 225)
# Image saved as res_at_iteration_291.png
# Iteration 291 completed in 2s
# Starting iteration 292 of 500
